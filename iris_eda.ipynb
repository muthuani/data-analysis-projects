# %%
# Iris Dataset Exploratory Data Analysis (EDA)

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
#url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
url = "iris.csv"
df = pd.read_csv(url)

# %%
# 1. Basic Exploration

print("🔹 First 5 rows of the dataset:")
display(df.head())

print("\n🔹 Dataset Info:")
print(df.info())

print("\n🔹 Shape of dataset:", df.shape)

print("\n🔹 Summary Statistics:")
display(df.describe())

print("\n🔹 Unique Species:", df['species'].unique())
print("\n🔹 Count of Each Species:")
display(df['species'].value_counts())
# Out:
# 🔹 First 5 rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# 🔹 Shape of dataset: (150, 5)
#
# 🔹 Summary Statistics:
# ...

# %%
# 2. Univariate Analysis

# Histograms
df.hist(figsize=(10, 8), bins=15)
plt.suptitle("Histogram of Iris Features")
plt.show()

# %%
# Boxplots by species
df.boxplot(column="sepal_length", by="species", figsize=(8, 6))
plt.title("Sepal Length Distribution by Species")
plt.suptitle("")
plt.show()

# %%
# 3. Bivariate Analysis

# Scatter plot sepal vs petal length
colors = {"setosa": "red", "versicolor": "green", "virginica": "blue"}
df.plot(kind="scatter", x="sepal_length", y="petal_length",
        c=df["species"].map(colors), figsize=(8, 6))
plt.title("Sepal Length vs Petal Length")
plt.show()

# %%
# Scatter matrix (pairwise relationships)
pd.plotting.scatter_matrix(df.iloc[:, :-1], figsize=(12, 10), diagonal="hist",
                           c=df["species"].map(colors))
plt.suptitle("Pairwise Relationships Between Features")
plt.show()

# %%
# 4. Grouped Statistics

print("\n🔹 Mean values grouped by species:")
display(df.groupby("species").mean())

print("\n🔹 Min values grouped by species:")
display(df.groupby("species").min())

print("\n🔹 Max values grouped by species:")
display(df.groupby("species").max())
# Out:
# 🔹 Mean values grouped by species:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
# 🔹 Min values grouped by species:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4
# 🔹 Max values grouped by species:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5
